# %% [markdown]
# ## Web Scraping Program

# %% [markdown]
# Design a web scraping program that retrieves the contents from an e-Commerce store that sells different tablet/laptop models in the following web scraping testing websites: https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets and https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops </br>
#
# Collect information for all the tablets and laptops listed on the webpage, including its product, description, price and review information.

# %%
# importing the library

import lxml.etree

import json

import warnings
warnings.filterwarnings("ignore")

# define a user-defined class ConsoleWriterPipeline(object) that receives the extract result from the spider 
# and prints out the content

class ConsoleWriterPipeline(object):
    def open_spider(self, spider):
        None
    def close_spdier(self, spider):
        None
    
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        print(line)
        return item

# %%
# importing the library

import logging
import scrapy
from scrapy.spiders import Rule, CrawlSpider
from scrapy.linkextractors import LinkExtractor

# Define the spider, TabletsCrawlSpider(CrawlSpider).

# Define the start Url

# 'https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets'

# Set the rule for the parsing in the URL

# Rule(LinkExtractor(allow=('/test-sites/e-commerce/allinone/product/')), 'parse_tablets_page')


class TabletsCrawlSpider(CrawlSpider):
    name = 'tablets-crawlspider'
    allowed_domains = ['webscraper.io']
    start_urls = ['https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets']
    custom_settings = {
      'LOG_LEVEL': logging.WARNING,
      'ITEM_PIPELINES': {'__main__.ConsoleWriterPipeline': 1} #, # Used for pipelines 1 and 2
      }
    rules = [
        Rule(
            LinkExtractor(allow=('/test-sites/e-commerce/allinone/product/')), 'parse_tablets_page'
        ),
    ]

    def parse_tablets_page(self, response):
        yield {
            #'type': response.css('a.subcategory-link.active::text').get(), response.css('a.subcategory-link.active ::attr(href)').extract()
            'description': response.css('p.description::text').get(),
            'price': response.css('h4::text').get(),
            'product':' '.join(response.css('h4::text')[1].re('[a-zA-Z0-9]+')),
            'review': ' '.join(response.css('.ratings ::text').re('[a-zA-Z0-9]+'))
        }

# %%
# importing the library

from scrapy import signals
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.signalmanager import dispatcher

# create a process which will start the crawler for tablets. 

def spider_tablet_results():
    
    results = []

    def crawler_results(signal, sender, item, response, spider):
        results.append(item)

    dispatcher.connect(crawler_results, signal=signals.item_scraped)

    hgw_crawler_process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)' # User Agent is the runner that execute the crawling process.
})
    hgw_crawler_process.crawl(TabletsCrawlSpider)
    
    hgw_crawler_process.start()  # the script will block here until the crawling is finished
    
    return results

# Print the output in JSON format

if __name__ == '__main__':
    json_tablet = json.dumps(spider_tablet_results(), indent=4)
    print(json_tablet)
# Out:
# 2022-06-25 05:03:06 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-06-25 05:03:06 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.3 3 May 2022), cryptography 37.0.2, Platform Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
# 2022-06-25 05:03:06 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# {"description": "7\" screen, Android", "price": "$69.99", "product": "Lenovo IdeaTab", "review": "7 reviews"}
#
# {"description": "16GB, White", "price": "$251.99", "product": "Galaxy Tab", "review": "14 reviews"}
#
# {"description": "Wi-Fi + Cellular, 32GB, Silver", "price": "$537.99", "product": "iPad Mini Retina", "review": "8 reviews"}
#
# {"description": "12.2\", 32GB, WiFi, Android 4.4, White", "price": "$489.99", "product": "Galaxy Note", "review": "9 reviews"}
#
# {"description": "10.1\", 32GB, Black", "price": "$587.99", "product": "Galaxy Note 10 1", "review": "6 reviews"}
#
# {"description": "White, 10.1\" IPS, 1.6GHz, 2GB, 16GB, Android 4.2", "price": "$320.99", "product": "MeMo PAD FHD 10", "review": "7 reviews"}
#
# {"description": "Wi-Fi, 64GB, Silver", "price": "$603.99", "product": "Apple iPad Air", "review": "7 reviews"}
#
# {"description": "10.1\", 3G, Android 4.0, Garnet Red", "price": "$399.99", "product": "Galaxy Note", "review": "12 reviews"}
#
# {"description": "LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black", "price": "$233.99", "product": "Galaxy Tab 4", "review": "1 reviews"}
#
# {"description": "Silver, 7\" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2", "price": "$172.99", "product": "IdeaTab S5000", "review": "8 reviews"}
#
# {"description": "Blue, 7\" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2", "price": "$148.99", "product": "IdeaTab A3500 H", "review": "9 reviews"}
#
# {"description": "White, 7\", Atom 1.2GHz, 8GB, Android 4.4", "price": "$130.99", "product": "MeMO Pad 7", "review": "11 reviews"}
#
# {"description": "6\" screen, wifi", "price": "$103.99", "product": "Amazon Kindle", "review": "3 reviews"}
#
# {"description": "7\" screen, Android, 8GB", "price": "$102.99", "product": "Asus MeMO Pad", "review": "14 reviews"}
#
# {"description": "7\", 8GB, Wi-Fi, Android 4.2, Yellow", "price": "$107.99", "product": "Galaxy Tab 3", "review": "14 reviews"}
#
# {"description": "IPS, Dual-Core 1.2GHz, 8GB, Android 4.3", "price": "$101.99", "product": "Memo Pad HD 7", "review": "10 reviews"}
#
# {"description": "Blue, 8\" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2", "price": "$121.99", "product": "IdeaTab A8 50", "review": "13 reviews"}
#
# {"description": "Black, 7\", 1.6GHz Dual-Core, 8GB, Android 4.4", "price": "$99.99", "product": "Iconia B1 730HD", "review": "1 reviews"}
#
# {"description": "7\", 8GB, Wi-Fi, Android 4.2, White", "price": "$97.99", "product": "Galaxy Tab 3", "review": "2 reviews"}
#
# {"description": "7\" screen, Android, 16GB", "price": "$96.99", "product": "Acer Iconia", "review": "7 reviews"}
#
# {"description": "Black, 7\" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2", "price": "$88.99", "product": "IdeaTab A3500L", "review": "7 reviews"}
#
# [
#     {
#         "description": "7\" screen, Android",
#         "price": "$69.99",
#         "product": "Lenovo IdeaTab",
#         "review": "7 reviews"
#     },
#     {
#         "description": "16GB, White",
#         "price": "$251.99",
#         "product": "Galaxy Tab",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Wi-Fi + Cellular, 32GB, Silver",
#         "price": "$537.99",
#         "product": "iPad Mini Retina",
#         "review": "8 reviews"
#     },
#     {
#         "description": "12.2\", 32GB, WiFi, Android 4.4, White",
#         "price": "$489.99",
#         "product": "Galaxy Note",
#         "review": "9 reviews"
#     },
#     {
#         "description": "10.1\", 32GB, Black",
#         "price": "$587.99",
#         "product": "Galaxy Note 10 1",
#         "review": "6 reviews"
#     },
#     {
#         "description": "White, 10.1\" IPS, 1.6GHz, 2GB, 16GB, Android 4.2",
#         "price": "$320.99",
#         "product": "MeMo PAD FHD 10",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Wi-Fi, 64GB, Silver",
#         "price": "$603.99",
#         "product": "Apple iPad Air",
#         "review": "7 reviews"
#     },
#     {
#         "description": "10.1\", 3G, Android 4.0, Garnet Red",
#         "price": "$399.99",
#         "product": "Galaxy Note",
#         "review": "12 reviews"
#     },
#     {
#         "description": "LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black",
#         "price": "$233.99",
#         "product": "Galaxy Tab 4",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Silver, 7\" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2",
#         "price": "$172.99",
#         "product": "IdeaTab S5000",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Blue, 7\" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2",
#         "price": "$148.99",
#         "product": "IdeaTab A3500 H",
#         "review": "9 reviews"
#     },
#     {
#         "description": "White, 7\", Atom 1.2GHz, 8GB, Android 4.4",
#         "price": "$130.99",
#         "product": "MeMO Pad 7",
#         "review": "11 reviews"
#     },
#     {
#         "description": "6\" screen, wifi",
#         "price": "$103.99",
#         "product": "Amazon Kindle",
#         "review": "3 reviews"
#     },
#     {
#         "description": "7\" screen, Android, 8GB",
#         "price": "$102.99",
#         "product": "Asus MeMO Pad",
#         "review": "14 reviews"
#     },
#     {
#         "description": "7\", 8GB, Wi-Fi, Android 4.2, Yellow",
#         "price": "$107.99",
#         "product": "Galaxy Tab 3",
#         "review": "14 reviews"
#     },
#     {
#         "description": "IPS, Dual-Core 1.2GHz, 8GB, Android 4.3",
#         "price": "$101.99",
#         "product": "Memo Pad HD 7",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Blue, 8\" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2",
#         "price": "$121.99",
#         "product": "IdeaTab A8 50",
#         "review": "13 reviews"
#     },
#     {
#         "description": "Black, 7\", 1.6GHz Dual-Core, 8GB, Android 4.4",
#         "price": "$99.99",
#         "product": "Iconia B1 730HD",
#         "review": "1 reviews"
#     },
#     {
#         "description": "7\", 8GB, Wi-Fi, Android 4.2, White",
#         "price": "$97.99",
#         "product": "Galaxy Tab 3",
#         "review": "2 reviews"
#     },
#     {
#         "description": "7\" screen, Android, 16GB",
#         "price": "$96.99",
#         "product": "Acer Iconia",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Black, 7\" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2",
#         "price": "$88.99",
#         "product": "IdeaTab A3500L",
#         "review": "7 reviews"
#     }
# ]

# %% [markdown]
# ### b) Search tablets’ information based on the review.

# %% [markdown]
# ### Function name: SearchbyReview( int review); Argument review: int

# %% [markdown]
# ### Return result: list of all matching items with (type, product, description, price, reviews) that have review greater than or equal to the function argument review. The list needs to be sorted base on the reviews in the descending order.

# %%
# importing the library

import pandas as pd

# Convert the JSON output into a dataframe using pd.read_json() and assign it to df_tablet

df_tablet = pd.read_json(json_tablet)
df_tablet
# Out:
#                                           description    price  \
# 0                                  7" screen, Android   $69.99
# 1                                         16GB, White  $251.99
# 2                      Wi-Fi + Cellular, 32GB, Silver  $537.99
# 3               12.2", 32GB, WiFi, Android 4.4, White  $489.99
# 4                                  10.1", 32GB, Black  $587.99
# 5    White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2  $320.99
# 6                                 Wi-Fi, 64GB, Silver  $603.99
# 7                  10.1", 3G, Android 4.0, Garnet Red  $399.99
# 8         LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black  $233.99
# 9   Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, An...  $172.99
# 10  Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Andro...  $148.99
# 11           White, 7", Atom 1.2GHz, 8GB, Android 4.4  $130.99
# 12                                    6" screen, wifi  $103.99
# 13                            7" screen, Android, 8GB  $102.99
# 14                7", 8GB, Wi-Fi, Android 4.2, Yellow  $107.99
# 15            IPS, Dual-Core 1.2GHz, 8GB, Android 4.3  $101.99
# 16  Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2  $121.99
# 17      Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4   $99.99
# 18                 7", 8GB, Wi-Fi, Android 4.2, White   $97.99
# 19                           7" screen, Android, 16GB   $96.99
# 20  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2   $88.99
#
#              product      review
# 0     Lenovo IdeaTab   7 reviews
# 1         Galaxy Tab  14 reviews
# 2   iPad Mini Retina   8 reviews
# 3        Galaxy Note   9 reviews
# 4   Galaxy Note 10 1   6 reviews
# 5    MeMo PAD FHD 10   7 reviews
# 6     Apple iPad Air   7 reviews
# 7        Galaxy Note  12 reviews
# 8       Galaxy Tab 4   1 reviews
# 9      IdeaTab S5000   8 reviews
# 10   IdeaTab A3500 H   9 reviews
# 11        MeMO Pad 7  11 reviews
# 12     Amazon Kindle   3 reviews
# 13     Asus MeMO Pad  14 reviews
# 14      Galaxy Tab 3  14 reviews
# 15     Memo Pad HD 7  10 reviews
# 16     IdeaTab A8 50  13 reviews
# 17   Iconia B1 730HD   1 reviews
# 18      Galaxy Tab 3   2 reviews
# 19       Acer Iconia   7 reviews
# 20    IdeaTab A3500L   7 reviews

# %%
# Create a new column "num_reviews" that extracts the numerical value of the "review" column

df_tablet['num_reviews'] = df_tablet['review'].apply(lambda x: x.replace("reviews", " ")).astype('int')
df_tablet
# Out:
#                                           description    price  \
# 0                                  7" screen, Android   $69.99
# 1                                         16GB, White  $251.99
# 2                      Wi-Fi + Cellular, 32GB, Silver  $537.99
# 3               12.2", 32GB, WiFi, Android 4.4, White  $489.99
# 4                                  10.1", 32GB, Black  $587.99
# 5    White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2  $320.99
# 6                                 Wi-Fi, 64GB, Silver  $603.99
# 7                  10.1", 3G, Android 4.0, Garnet Red  $399.99
# 8         LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black  $233.99
# 9   Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, An...  $172.99
# 10  Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Andro...  $148.99
# 11           White, 7", Atom 1.2GHz, 8GB, Android 4.4  $130.99
# 12                                    6" screen, wifi  $103.99
# 13                            7" screen, Android, 8GB  $102.99
# 14                7", 8GB, Wi-Fi, Android 4.2, Yellow  $107.99
# 15            IPS, Dual-Core 1.2GHz, 8GB, Android 4.3  $101.99
# 16  Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2  $121.99
# 17      Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4   $99.99
# 18                 7", 8GB, Wi-Fi, Android 4.2, White   $97.99
# 19                           7" screen, Android, 16GB   $96.99
# 20  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2   $88.99
#
#              product      review  num_reviews
# 0     Lenovo IdeaTab   7 reviews            7
# 1         Galaxy Tab  14 reviews           14
# 2   iPad Mini Retina   8 reviews            8
# 3        Galaxy Note   9 reviews            9
# 4   Galaxy Note 10 1   6 reviews            6
# 5    MeMo PAD FHD 10   7 reviews            7
# 6     Apple iPad Air   7 reviews            7
# 7        Galaxy Note  12 reviews           12
# 8       Galaxy Tab 4   1 reviews            1
# 9      IdeaTab S5000   8 reviews            8
# 10   IdeaTab A3500 H   9 reviews            9
# 11        MeMO Pad 7  11 reviews           11
# 12     Amazon Kindle   3 reviews            3
# 13     Asus MeMO Pad  14 reviews           14
# 14      Galaxy Tab 3  14 reviews           14
# 15     Memo Pad HD 7  10 reviews           10
# 16     IdeaTab A8 50  13 reviews           13
# 17   Iconia B1 730HD   1 reviews            1
# 18      Galaxy Tab 3   2 reviews            2
# 19       Acer Iconia   7 reviews            7
# 20    IdeaTab A3500L   7 reviews            7

# %%
# define a function SearchbyReview(int_review) that returns a list of matching items with number of reviews more than or 
# equals to the parameter, int_review
# The list needs to be sorted based on the reviews in the descending order.

def SearchbyReview(int_review):
    """returns number of reviews more than or equals to the int_review"""
    return df_tablet[df_tablet['num_reviews'] >= int_review].sort_values(by = ['num_reviews'], ascending = False).drop('num_reviews', axis = 1).values.tolist()

# %% [markdown]
# ### Run the function with review=8 and review=14. Print the results of each of the review.

# %%
# when review = 8
SearchbyReview(8)
# Out:
# [['16GB, White', '$251.99', 'Galaxy Tab', '14 reviews'],
#  ['7" screen, Android, 8GB', '$102.99', 'Asus MeMO Pad', '14 reviews'],
#  ['7", 8GB, Wi-Fi, Android 4.2, Yellow',
#   '$107.99',
#   'Galaxy Tab 3',
#   '14 reviews'],
#  ['Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2',
#   '$121.99',
#   'IdeaTab A8 50',
#   '13 reviews'],
#  ['10.1", 3G, Android 4.0, Garnet Red',
#   '$399.99',
#   'Galaxy Note',
#   '12 reviews'],
#  ['White, 7", Atom 1.2GHz, 8GB, Android 4.4',
#   '$130.99',
#   'MeMO Pad 7',
#   '11 reviews'],
#  ['IPS, Dual-Core 1.2GHz, 8GB, Android 4.3',
#   '$101.99',
#   'Memo Pad HD 7',
#   '10 reviews'],
#  ['12.2", 32GB, WiFi, Android 4.4, White',
#   '$489.99',
#   'Galaxy Note',
#   '9 reviews'],
#  ['Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2',
#   '$148.99',
#   'IdeaTab A3500 H',
#   '9 reviews'],
#  ['Wi-Fi + Cellular, 32GB, Silver',
#   '$537.99',
#   'iPad Mini Retina',
#   '8 reviews'],
#  ['Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2',
#   '$172.99',
#   'IdeaTab S5000',
#   '8 reviews']]

# %%
# when review = 14
SearchbyReview(14)
# Out:
# [['16GB, White', '$251.99', 'Galaxy Tab', '14 reviews'],
#  ['7" screen, Android, 8GB', '$102.99', 'Asus MeMO Pad', '14 reviews'],
#  ['7", 8GB, Wi-Fi, Android 4.2, Yellow',
#   '$107.99',
#   'Galaxy Tab 3',
#   '14 reviews']]

# %% [markdown]
# ## Repeat the same for Laptop scrapping

# %%
import lxml.etree

import json

# define a user-defined class ConsoleWriterPipeline(object) that receives the extract result from the spider 
# and prints out the content

class ConsoleWriterPipeline(object):
    def open_spider(self, spider):
        None
    def close_spdier(self, spider):
        None
    
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        return item

# %%
# importing the library

import logging
import scrapy
from scrapy.spiders import Rule, CrawlSpider
from scrapy.linkextractors import LinkExtractor

# Define the spider, LaptopsCrawlSpider(CrawlSpider).

# Define the start Url

# 'https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops'

# Set the rule for the parsing in the URL

# Rule(LinkExtractor(allow=('/test-sites/e-commerce/allinone/product/')), 'parse_tablets_page')

class LaptopsCrawlSpider(CrawlSpider):
    name = 'Laptops-crawlspider'
    allowed_domains = ['webscraper.io']
    start_urls = ['https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops']
    custom_settings = {
      'LOG_LEVEL': logging.WARNING,
      'ITEM_PIPELINES': {'__main__.ConsoleWriterPipeline': 1}#, # Used for pipeline 1
      }
    rules = [
        Rule(
            LinkExtractor(allow=('/test-sites/e-commerce/allinone/product/')), 'parse_laptops_page'
        ),
    ]

    def parse_laptops_page(self, response):
        yield {
            #'type': response.css('a.subcategory-link.active::attr(href)').extract(),
            'description': response.css('p.description::text').get(),
            'price': response.css('h4::text').get(),
            'product':' '.join(response.css('h4::text')[1].re('[a-zA-Z0-9]+')),
            'review': ' '.join(response.css('.ratings ::text').re('[a-zA-Z0-9]+'))
        }

# %%
# importing the library

from scrapy import signals
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.signalmanager import dispatcher
import sys

# create a process which will start the crawler for laptops. 

def spider_laptops_results():
    results = []

    def crawler_results(signal, sender, item, response, spider):
        results.append(item)

    dispatcher.connect(crawler_results, signal=signals.item_scraped)

    hgw_crawler_process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
    hgw_crawler_process.crawl(LaptopsCrawlSpider)
    hgw_crawler_process.start()  # the script will block here until the crawling is finished
    return results

# Print the output in JSON format

if __name__ == '__main__':
    json_laptop = json.dumps(spider_laptops_results(), indent=4)
    print(json_laptop)
# Out:
# 2022-06-25 05:05:29 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-06-25 05:05:29 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.3 3 May 2022), cryptography 37.0.2, Platform Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
# 2022-06-25 05:05:29 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# [
#     {
#         "description": "Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd",
#         "price": "$295.99",
#         "product": "Asus VivoBook X441NA GA190",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Acer Aspire A315-51-33TG, Black 15.6\" HD, Core i3-7100U, 4GB DDR4, 128GB SSD, Windows 10 Home, ENG",
#         "price": "$457.38",
#         "product": "Acer Aspire A315 51 33TG",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam",
#         "price": "$299.00",
#         "product": "Prestigio SmartBook 133S Dark Grey",
#         "review": "8 reviews"
#     },
#     {
#         "description": "15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux",
#         "price": "$306.99",
#         "product": "Aspire E1 510",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$372.70",
#         "product": "Acer Aspire 3 A315 31 Black",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS",
#         "price": "$364.46",
#         "product": "Hewlett Packard 250 G6 Dark Ash Silver",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$321.94",
#         "product": "Lenovo V110 15IAP",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam",
#         "price": "$299.00",
#         "product": "Prestigio SmartBook 133S Gold",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Pro",
#         "price": "$454.73",
#         "product": "Lenovo V110 15ISK",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd",
#         "price": "$356.49",
#         "product": "Lenovo V110 15IAP",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-572 Black, 15.6\" HD, Core i5-7200U, 4GB, 500GB, Linux",
#         "price": "$454.62",
#         "product": "Acer Aspire ES1 572 Black",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Acer Extensa 15 (2540) Black, 15.6\" HD, Core i5-7200U, 4GB, 500GB, Linux",
#         "price": "$439.73",
#         "product": "Acer Extensa 15 2540 Black",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home",
#         "price": "$436.29",
#         "product": "Acer Aspire ES1 572 Black",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd",
#         "price": "$433.30",
#         "product": "Asus EeeBook R416NA FA014T",
#         "review": "1 reviews"
#     },
#     {
#         "description": "15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1",
#         "price": "$416.99",
#         "product": "Packard 255 G2",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home",
#         "price": "$436.29",
#         "product": "Acer Aspire 3 A315 51",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd",
#         "price": "$410.66",
#         "product": "Asus VivoBook 15 X540NA GQ026T",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Asus ROG Strix SCAR Edition GL503VM-ED115T, 15.6\" FHD 120Hz, Core i7-7700HQ, 16GB, 256GB SSD + 1TB SSHD, GeForce GTX 1060 6GB, Windows 10 Home",
#         "price": "$1799.00",
#         "product": "Asus ROG Strix SCAR Edition GL503VM ED115T",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Asus ROG Strix GL702ZC-GC154T, 17.3\" FHD, Ryzen 7 1700, 16GB, 256GB + 1TB HDD, Radeon RX 580 4GB, Windows 10 Home",
#         "price": "$1769.00",
#         "product": "Asus ROG Strix GL702ZC GC154T",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Asus ROG Strix GL702ZC-GC209T, 17.3\" FHD IPS, Ryzen 7 1700, 16GB, 256GB SSD + 1TB HDD, Radeon RX 580 4GB, Windows 10 Home",
#         "price": "$1769.00",
#         "product": "Asus ROG Strix GL702ZC GC209T",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Lenovo ThinkPad Yoga 370 Black, 13.3\" FHD IPS Touch, Core i5-7200U, 8GB, 256GB SSD, 4G, Windows 10 Pro",
#         "price": "$1362.24",
#         "product": "Lenovo ThinkPad Yoga 370 Black",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Toshiba Portege X20W-D-10V Black/Blue, 12.5\" FHD Touch, Core i7-7500U, 8GB, 512GB SSD, Windows 10 Pro",
#         "price": "$1366.32",
#         "product": "Toshiba Portege X20W D 10V Black Blue",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Asus ROG Strix GL702VM-GC146T, 17.3\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1060 3GB, Windows 10 Home, Eng kbd",
#         "price": "$1399.00",
#         "product": "Asus ROG Strix GL702VM GC146T",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Lenovo ThinkPad T470, 14\" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1349.23",
#         "product": "Lenovo ThinkPad T470",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Apple MacBook Air 13\", Intel Core i5 1.8GHz, 8GB, 256GB SSD, Intel HD 6000, RUS",
#         "price": "$1347.78",
#         "product": "Apple MacBook Air 13",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Dell Latitude 5580, 15.6\" FHD, Core i7-7600U, 16GB, 256GB SSD, GeForce GT930MX, Linux",
#         "price": "$1341.22",
#         "product": "Dell Latitude 5580",
#         "review": "3 reviews"
#     },
#     {
#         "description": "Lenovo Legion Y720, 15.6\" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 2TB HDD, GeForce GTX 1060 6GB, DOS, RGB backlit keyboard",
#         "price": "$1399.00",
#         "product": "Lenovo Legion Y720",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Asus ASUSPRO B9440UA-GV0279R Gray, 14\" FHD, Core i7-7500U, 16GB, 512GB SSD, Windows 10 Pro, Eng kbd",
#         "price": "$1381.13",
#         "product": "Asus ASUSPRO B9440UA GV0279R Gray",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i7-7600U, 8GB, 256GB SSD, Linux + Windows 10 Home",
#         "price": "$1338.37",
#         "product": "Dell Latitude 5480",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Dell Latitude 5580, 15.6\" FHD, Core i7-7600U, 8GB, 256GB SSD, GeForce GT930MX, Windows 10 Pro",
#         "price": "$1337.28",
#         "product": "Dell Latitude 5580",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Apple MacBook Pro 13\" Space Gray, Core i5 2.3GHz, 8GB, 128GB SSD, Iris Plus 640, ENG",
#         "price": "$1333.00",
#         "product": "Apple MacBook Pro 13 Space Gray",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Hewlett Packard ProBook 640 G3, 14\" FHD, Core i7-7600U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1326.83",
#         "product": "Hewlett Packard ProBook 640 G3",
#         "review": "2 reviews"
#     },
#     {
#         "description": "12.5\", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro 64bit",
#         "price": "$1311.99",
#         "product": "ThinkPad X240",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Toshiba Portege Z30-C-16K Grey, 13.3\" FHD, Core i5-6200U, 8GB, 256GB SSD, 4G, Windows 10 Pro",
#         "price": "$1294.74",
#         "product": "Toshiba Portege Z30 C 16K Grey",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i7-7600U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1310.39",
#         "product": "Dell Latitude 5480",
#         "review": "8 reviews"
#     },
#     {
#         "description": "MSI GL62VR 7RFX, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB + 256GB SSD, GeForce GTX 1060 3GB, Windows 10 Home",
#         "price": "$1299.00",
#         "product": "MSI GL62VR 7RFX",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Apple MacBook Air 13\", i5 1.8GHz, 8GB, 256GB SSD, Intel HD 6000, ENG",
#         "price": "$1260.13",
#         "product": "Apple MacBook Air 13",
#         "review": "8 reviews"
#     },
#     {
#         "description": "13.3\" Touch, Core i5-4210U, 8GB, 128GB SSD, Windows 8.1",
#         "price": "$1281.99",
#         "product": "Dell XPS 13",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Hewlett Packard Spectre 13-v106na Dark Ash Silver, 13.3\" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Home",
#         "price": "$1273.11",
#         "product": "Hewlett Packard Spectre 13 v106na Dark Ash Silver",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i7-7600U, 8GB, 1TB, GeForce GT930MX, Windows 10 Pro",
#         "price": "$1271.06",
#         "product": "Dell Latitude 5480",
#         "review": "13 reviews"
#     },
#     {
#         "description": "Asus ROG Strix GL753VE-GC096T, 17.3\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 4GB, Windows 10 Home, Eng kbd",
#         "price": "$1259.00",
#         "product": "Asus ROG Strix GL753VE GC096T",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Asus ZenBook UX530UX-FY040T Blue, 15.6\" FHD, Core i7-7500U, 8GB, 512GB SSD, GeForce GTX950M 2GB, Windows 10 Home, Eng kbd",
#         "price": "$1239.20",
#         "product": "Asus ZenBook UX530UX FY040T Blue",
#         "review": "14 reviews"
#     },
#     {
#         "description": "12.5\", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pro 64bit",
#         "price": "$1244.99",
#         "product": "ThinkPad X230",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Asus VivoBook Pro 15 N580VN-FI006T Gold Metal, 15.6\" UHD, Core i7-7700HQ, 16GB, 1TB + 256GB SSD, GeForce MX150 2GB, Windows 10 Home, Eng kbd",
#         "price": "$1235.49",
#         "product": "Asus VivoBook Pro 15 N580VN FI006T Gold Metal",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Acer Predator Helios 300 (PH317-51), 17.3\" FHD IPS, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 4GB, Windows 10 Home",
#         "price": "$1221.58",
#         "product": "Acer Predator Helios 300 PH317 51",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i7-7600U, 8GB, 256GB SSD, Linux",
#         "price": "$1238.37",
#         "product": "Dell Latitude 5480",
#         "review": "0 reviews"
#     },
#     {
#         "description": "12.5\" Touch, Core i5 4200U, 8GB, 500GB + 16GB SSD Cache, Windows",
#         "price": "$1223.99",
#         "product": "ThinkPad Yoga",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Lenovo IdeaPad Miix 510 Platinum Silver, 12.2\" IPS Touch, Core i5-7200U, 8GB, 256GB SSD, 4G, Windows 10 Pro",
#         "price": "$1212.16",
#         "product": "Lenovo IdeaPad Miix 510 Platinum Silver",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Toshiba Portege X30-D-10J Black/Blue, 13.3\" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1203.41",
#         "product": "Toshiba Portege X30 D 10J Black Blue",
#         "review": "13 reviews"
#     },
#     {
#         "description": "15.6\", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit",
#         "price": "$1178.99",
#         "product": "ThinkPad T540p",
#         "review": "2 reviews"
#     },
#     {
#         "description": "MSI GL62M 7REX2, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home",
#         "price": "$1199.00",
#         "product": "MSI GL62M 7REX2",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1187.88",
#         "product": "Dell Latitude 5480",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Acer Predator Helios 300 (PH317-51), 17.3\" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home",
#         "price": "$1187.98",
#         "product": "Acer Predator Helios 300 PH317 51",
#         "review": "14 reviews"
#     },
#     {
#         "description": "MSI GS63 7RD Stealth, 15.6\" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, DOS + Windows 10 Home",
#         "price": "$1179.00",
#         "product": "MSI GS63 7RD Stealth",
#         "review": "2 reviews"
#     },
#     {
#         "description": "MSI GL62M 7REX, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home",
#         "price": "$1199.00",
#         "product": "MSI GL62M 7REX",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Dell Latitude 5580, 15.6\" FHD, Core i5-7300U, 16GB, 256GB SSD, Linux + Windows 10 Home",
#         "price": "$1178.19",
#         "product": "Dell Latitude 5580",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Lenovo Yoga 910 Grey, 13.9\" FHD Touch, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Home",
#         "price": "$1199.73",
#         "product": "Lenovo Yoga 910 Grey",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Dell Latitude 5580, 15.6\" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1144.40",
#         "product": "Dell Latitude 5580",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Lenovo Yoga 720 Grey, 15.6\" FHD IPS, Core i5-7300HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, Windows 10 Home",
#         "price": "$1149.73",
#         "product": "Lenovo Yoga 720 Grey",
#         "review": "12 reviews"
#     },
#     {
#         "description": "MSI GP62M 7RDX Leopard, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home",
#         "price": "$1149.00",
#         "product": "MSI GP62M 7RDX Leopard",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Lenovo Legion Y520-15IKBM, 15.6\" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 1TB, GeForce GTX 1060 Max-Q 6GB, DOS",
#         "price": "$1149.00",
#         "product": "Lenovo Legion Y520 15IKBM",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i5-7440HQ, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1143.40",
#         "product": "Dell Latitude 5480",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Toshiba Portege Z30-C-16L Grey, 13.3\" FHD, Core i7-6500U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1154.04",
#         "product": "Toshiba Portege Z30 C 16L Grey",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Acer TravelMate P645-S-511A Black, 14\" FHD IPS, Core i5-5200U, 8GB, 256GB SSD, 3G, Windows 10 Pro",
#         "price": "$1170.10",
#         "product": "Acer TravelMate P645 S 511A Black",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Dell Inspiron 15 (7567) Black, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB, GeForce GTX 1050 Ti 4GB, Linux + Windows 10 Home",
#         "price": "$1144.20",
#         "product": "Dell Inspiron 15 7567 Black",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Acer Nitro 5 AN515-51, 15.6\" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD +1TB, GeForce GTX 1050 Ti 4GB, Windows 10 Home + Windows 10 Home",
#         "price": "$1140.62",
#         "product": "Acer Nitro 5 AN515 51",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Lenovo Legion Y520, 15.6\" FHD, Core i7-7700HQ, 8GB, 128 GB SSD + 1TB HDD, GTX 1050 4GB, Windows 10 Home",
#         "price": "$1133.91",
#         "product": "Lenovo Legion Y520",
#         "review": "13 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i5-7300U, 8GB, 500GB, Windows 10 Pro",
#         "price": "$1133.82",
#         "product": "Dell Latitude 5480",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Dell Inspiron 17 2in1 (7779) Silver, 17.3\" FHD Touch, Core i5-7200U, 12GB, 1TB, GeForce GT940MX 2GB, Windows 10 Home",
#         "price": "$1124.20",
#         "product": "Dell Inspiron 17 2in1 7779 Silver",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Acer Predator Helios 300 (PH317-51), 17.3\" FHD IPS, Core i5-7300HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050Ti 4GB, Windows 10 Home",
#         "price": "$1123.87",
#         "product": "Acer Predator Helios 300 PH317 51",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Toshiba Portege Z30-C-16J Grey, 13.3\" FHD, Core i5-6200U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1114.55",
#         "product": "Toshiba Portege Z30 C 16J Grey",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Acer Aspire 7 A715-71G, 15.6\" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 1TB HDD, GTX 1050 Ti 4GB, Windows 10 Home",
#         "price": "$1123.87",
#         "product": "Acer Aspire 7 A715 71G",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Asus AsusPro Advanced BU401LA-FA271G Dark Grey, 14\", Core i5-4210U, 4GB, 128GB SSD, Win7 Pro 64bit, ENG",
#         "price": "$1139.54",
#         "product": "Asus AsusPro Advanced BU401LA FA271G Dark Grey",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Lenovo Legion Y520-15IKBM, Black, 15.6\" FHD IPS, Core i5-7300HQ, 8 GB, 128GB SSD + 2 TB HDD, NVIDIA GeForce GTX 1060 6 GB, FreeDOS + Windows 10 Home",
#         "price": "$1112.91",
#         "product": "Lenovo Legion Y520 15IKBM",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Apple MacBook Air 13.3\", Core i5 1.8GHz, 8GB, 128GB SSD, Intel HD 4000, RUS",
#         "price": "$1101.83",
#         "product": "Asus ROG Strix GL553VD DM535T",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Asus ROG Strix GL553VD-DM535T, 15.6\" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home, Eng kbd",
#         "price": "$1099.00",
#         "product": "MSI GL72M 7RDX",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Dell Latitude 5480, 14\" FHD, Core i5-7300U, 8GB, 500GB, Linux + Windows 10 Home",
#         "price": "$1110.14",
#         "product": "Dell Latitude 5480",
#         "review": "4 reviews"
#     },
#     {
#         "description": "MSI GL72M 7RDX, 17.3\" FHD, Core i5-7300HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home",
#         "price": "$1099.00",
#         "product": "MSI GL72M 7RDX",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Dell Latitude 5280, 12.5\" HD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1102.66",
#         "product": "Dell Latitude 5280",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Dell Inspiron 15 (7567) Black, 15.6\" FHD, Core i5-7300HQ, 8GB, 256GB SSD, GeForce GTX 1050 4GB, Windows 10 Home",
#         "price": "$1098.42",
#         "product": "Dell Inspiron 15 7567 Black",
#         "review": "7 reviews"
#     },
#     {
#         "description": "12.5\" Touch, Core i3-4010U, 4GB, 500GB + 16GB SSD Cache,",
#         "price": "$1033.99",
#         "product": "ThinkPad Yoga",
#         "review": "13 reviews"
#     },
#     {
#         "description": "Lenovo ThinkPad L460, 14\" FHD IPS, Core i7-6600U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$1096.02",
#         "product": "Lenovo ThinkPad L460",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Acer Nitro 5 AN515-51, 15.6\" FHD IPS, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, Windows 10 Home",
#         "price": "$809.00",
#         "product": "Acer Nitro 5 AN515 51",
#         "review": "0 reviews"
#     },
#     {
#         "description": "14\", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit",
#         "price": "$739.99",
#         "product": "ProBook",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Lenovo ThinkPad L570, 15.6\" FHD, Core i7-7500U, 8GB, 256GB SSD, Windows 10 Pro",
#         "price": "$999.00",
#         "product": "Lenovo ThinkPad L570",
#         "review": "11 reviews"
#     },
#     {
#         "description": "Asus ROG STRIX GL553VD-DM256, 15.6\" FHD, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, No OS + Windows 10 Home",
#         "price": "$899.00",
#         "product": "Asus ROG STRIX GL553VD DM256",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Moon Silver, 15.6\", Core i7-4510U, 8GB, 1TB, Radeon HD R7 M265 2GB,",
#         "price": "$745.99",
#         "product": "Inspiron 15",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Asus ROG STRIX GL553VD-DM256, 15.6\" FHD, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, No OS",
#         "price": "$799.00",
#         "product": "Asus ROG STRIX GL553VD DM256",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Asus VivoBook S14 (S406UA-BV041T) Starry Grey, 14\", Core i5-8250U, 8GB, 256GB SSD, Windows 10 Home, Eng kbd",
#         "price": "$729.00",
#         "product": "Asus VivoBook S14",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Dell Inspiron 15 (5567) Fog Gray, 15.6\" FHD, Core i5-7200U, 8GB, 1TB, Radeon R7 M445 4GB, Linux",
#         "price": "$679.00",
#         "product": "Dell Inspiron 15",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Acer Aspire A515-51-5654, Black, 15.6\", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG",
#         "price": "$679.00",
#         "product": "Acer Aspire A515 51 5654",
#         "review": "9 reviews"
#     },
#     {
#         "description": "15.6\", Core i5-4200U, 8GB, 1TB, Radeon R7 M265, Windows 8.1",
#         "price": "$581.99",
#         "product": "Aspire E1 572G",
#         "review": "2 reviews"
#     },
#     {
#         "description": "15.6\", Core i5-4200U, 4GB, 750GB, Radeon HD8670M 2GB, Windows",
#         "price": "$577.99",
#         "product": "HP 350 G1",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Acer Spin 5 SP513-51 Black, 13.3\" FHD Touch, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$564.98",
#         "product": "Acer Spin 5",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Lenovo V510 Black, 15.6\" FHD, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Pro",
#         "price": "$498.23",
#         "product": "Lenovo V510 Black",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Dell Vostro 15 (3568) Red, 15.6\" HD, Core i5-7200U, 4GB, 1TB, Radeon R5 M420 2GB, Linux",
#         "price": "$497.17",
#         "product": "Dell Vostro 15 3568 Red",
#         "review": "9 reviews"
#     },
#     {
#         "description": "15.6\", Core i5-4200U, 6GB, 750GB, Windows 8.1",
#         "price": "$609.99",
#         "product": "Pavilion",
#         "review": "4 reviews"
#     },
#     {
#         "description": "15.6\", Core\u00a0i5-4210U, 4GB, 500GB, Windows 8.1",
#         "price": "$520.99",
#         "product": "HP 250 G3",
#         "review": "13 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-51 Black, 15.6\" FHD, Core i3-7100U, 4GB, 500GB + 128GB SSD, Windows 10 Home",
#         "price": "$494.71",
#         "product": "Acer Aspire 3 A315 51 Black",
#         "review": "2 reviews"
#     },
#     {
#         "description": "Dell Vostro 15 (3568) Black, 15.6\" FHD, Core i5-7200U, 4GB, 128GB SSD, Radeon R5 M420 2GB, Linux",
#         "price": "$488.78",
#         "product": "Dell Vostro 15",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Acer Swift 1 SF113-31 Silver, 13.3\" FHD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$488.64",
#         "product": "Acer Swift 1 SF113 31 Silver",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Lenovo V510 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$487.80",
#         "product": "Lenovo V510 Black",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-572 Black, 15.6\" HD, Core i5-7200U, 4GB, 128GB SSD, Linux",
#         "price": "$485.90",
#         "product": "Acer Aspire ES1 572 Black",
#         "review": "6 reviews"
#     },
#     {
#         "description": "Lenovo V110-15IKB, 15.6\" HD, Core i5-7200U, 4GB, 500GB, DOS",
#         "price": "$465.95",
#         "product": "Lenovo V110 15IKB",
#         "review": "7 reviews"
#     },
#     {
#         "description": "Lenovo V510 Black, 14\" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$484.23",
#         "product": "Lenovo V510 Black",
#         "review": "8 reviews"
#     },
#     {
#         "description": "Asus VivoBook 15 X540UA-DM260 Chocolate Black, 15.6\" FHD, Core i3-6006U, 4GB, 256GB SSD, Endless OS, En kbd",
#         "price": "$468.56",
#         "product": "Asus VivoBook 15 X540UA DM260 Chocolate Black",
#         "review": "1 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$469.10",
#         "product": "Acer Aspire ES1 572 Black",
#         "review": "5 reviews"
#     },
#     {
#         "description": "Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home",
#         "price": "$409.63",
#         "product": "Lenovo V110 15ISK",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$408.98",
#         "product": "Acer Aspire 3 A315 31 Black",
#         "review": "10 reviews"
#     },
#     {
#         "description": "Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd",
#         "price": "$399.99",
#         "product": "Asus VivoBook E502NA GO022T Dark Blue",
#         "review": "3 reviews"
#     },
#     {
#         "description": "Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$404.23",
#         "product": "Lenovo ThinkPad E31 80",
#         "review": "12 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home",
#         "price": "$410.46",
#         "product": "Acer Aspire ES1 732 Black",
#         "review": "14 reviews"
#     },
#     {
#         "description": "Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home",
#         "price": "$399.00",
#         "product": "Asus VivoBook Max",
#         "review": "4 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux",
#         "price": "$393.88",
#         "product": "Acer Aspire 3 A315 21",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux",
#         "price": "$379.95",
#         "product": "Acer Aspire ES1 572 Black",
#         "review": "9 reviews"
#     },
#     {
#         "description": "Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG",
#         "price": "$379.94",
#         "product": "Acer Aspire A315 31 C33J",
#         "review": "0 reviews"
#     },
#     {
#         "description": "Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home",
#         "price": "$391.48",
#         "product": "Acer Aspire 3 A315 31 Black",
#         "review": "10 reviews"
#     }
# ]

# %%
# importing the library

import pandas as pd

# Convert the JSON output into a dataframe using pd.read_json() and assign it to df_laptop

df_laptop = pd.read_json(json_laptop)
df_laptop
# Out:
#                                            description    price  \
# 0    Asus VivoBook X441NA-GA190 Chocolate Black, 14...  $295.99
# 1    Acer Aspire A315-51-33TG, Black 15.6" HD, Core...  $457.38
# 2    Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...  $299.00
# 3      15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux  $306.99
# 4    Acer Aspire 3 A315-31 Black, 15.6" HD, Celeron...  $372.70
# ..                                                 ...      ...
# 112  Asus VivoBook Max X541NA-GQ041 Black Chocolate...  $399.00
# 113  Acer Aspire 3 A315-21, 15.6", AMD A4-9120. 4GB...  $393.88
# 114  Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6...  $379.95
# 115  Acer Aspire A315-31-C33J Black 15.6", HD, Cele...  $379.94
# 116  Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium...  $391.48
#
#                                 product      review
# 0            Asus VivoBook X441NA GA190  14 reviews
# 1              Acer Aspire A315 51 33TG   9 reviews
# 2    Prestigio SmartBook 133S Dark Grey   8 reviews
# 3                         Aspire E1 510   2 reviews
# 4           Acer Aspire 3 A315 31 Black   2 reviews
# ..                                  ...         ...
# 112                   Asus VivoBook Max   4 reviews
# 113               Acer Aspire 3 A315 21   9 reviews
# 114           Acer Aspire ES1 572 Black   9 reviews
# 115            Acer Aspire A315 31 C33J   0 reviews
# 116         Acer Aspire 3 A315 31 Black  10 reviews
#
# [117 rows x 4 columns]

# %%
# Create a new column "num_reviews" that extracts the numerical value of the "review" column

df_laptop['num_reviews'] = df_laptop['review'].apply(lambda x: x.replace("reviews", " ")).astype('int')
df_laptop
# Out:
#                                            description    price  \
# 0    Asus VivoBook X441NA-GA190 Chocolate Black, 14...  $295.99
# 1    Acer Aspire A315-51-33TG, Black 15.6" HD, Core...  $457.38
# 2    Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...  $299.00
# 3      15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux  $306.99
# 4    Acer Aspire 3 A315-31 Black, 15.6" HD, Celeron...  $372.70
# ..                                                 ...      ...
# 112  Asus VivoBook Max X541NA-GQ041 Black Chocolate...  $399.00
# 113  Acer Aspire 3 A315-21, 15.6", AMD A4-9120. 4GB...  $393.88
# 114  Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6...  $379.95
# 115  Acer Aspire A315-31-C33J Black 15.6", HD, Cele...  $379.94
# 116  Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium...  $391.48
#
#                                 product      review  num_reviews
# 0            Asus VivoBook X441NA GA190  14 reviews           14
# 1              Acer Aspire A315 51 33TG   9 reviews            9
# 2    Prestigio SmartBook 133S Dark Grey   8 reviews            8
# 3                         Aspire E1 510   2 reviews            2
# 4           Acer Aspire 3 A315 31 Black   2 reviews            2
# ..                                  ...         ...          ...
# 112                   Asus VivoBook Max   4 reviews            4
# 113               Acer Aspire 3 A315 21   9 reviews            9
# 114           Acer Aspire ES1 572 Black   9 reviews            9
# 115            Acer Aspire A315 31 C33J   0 reviews            0
# 116         Acer Aspire 3 A315 31 Black  10 reviews           10
#
# [117 rows x 5 columns]

# %%
# define a function SearchbyReview(int_review) that returns a list of matching items with number of reviews more than or 
# equals to the parameter, int_review
# The list needs to be sorted based on the reviews in the descending order.

def SearchbyReview(int_review):
    """returns number of reviews more than or equals to the int_review"""
    return df_laptop[df_laptop['num_reviews'] >= int_review].sort_values(by = ['num_reviews'], ascending = False).drop('num_reviews', axis = 1).values.tolist()

# %%
# when review = 8
SearchbyReview(8)
# Out:
# [['Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   '$295.99',
#   'Asus VivoBook X441NA GA190',
#   '14 reviews'],
#  ['Acer Aspire ES1-732 Black, 17.3" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home',
#   '$410.46',
#   'Acer Aspire ES1 732 Black',
#   '14 reviews'],
#  ['Dell Vostro 15 (3568) Black, 15.6" FHD, Core i5-7200U, 4GB, 128GB SSD, Radeon R5 M420 2GB, Linux',
#   '$488.78',
#   'Dell Vostro 15',
#   '14 reviews'],
#  ['Lenovo ThinkPad L460, 14" FHD IPS, Core i7-6600U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1096.02',
#   'Lenovo ThinkPad L460',
#   '14 reviews'],
#  ['Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 500GB, Windows 10 Pro',
#   '$1133.82',
#   'Dell Latitude 5480',
#   '14 reviews'],
#  ['Acer Nitro 5 AN515-51, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD +1TB, GeForce GTX 1050 Ti 4GB, Windows 10 Home + Windows 10 Home',
#   '$1140.62',
#   'Acer Nitro 5 AN515 51',
#   '14 reviews'],
#  ['Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home',
#   '$1187.98',
#   'Acer Predator Helios 300 PH317 51',
#   '14 reviews'],
#  ['Asus ZenBook UX530UX-FY040T Blue, 15.6" FHD, Core i7-7500U, 8GB, 512GB SSD, GeForce GTX950M 2GB, Windows 10 Home, Eng kbd',
#   '$1239.20',
#   'Asus ZenBook UX530UX FY040T Blue',
#   '14 reviews'],
#  ['Dell Latitude 5480, 14" FHD, Core i7-7600U, 8GB, 1TB, GeForce GT930MX, Windows 10 Pro',
#   '$1271.06',
#   'Dell Latitude 5480',
#   '13 reviews'],
#  ['15.6", Core\xa0i5-4210U, 4GB, 500GB, Windows 8.1',
#   '$520.99',
#   'HP 250 G3',
#   '13 reviews'],
#  ['12.5" Touch, Core i3-4010U, 4GB, 500GB + 16GB SSD Cache,',
#   '$1033.99',
#   'ThinkPad Yoga',
#   '13 reviews'],
#  ['Lenovo Legion Y520, 15.6" FHD, Core i7-7700HQ, 8GB, 128 GB SSD + 1TB HDD, GTX 1050 4GB, Windows 10 Home',
#   '$1133.91',
#   'Lenovo Legion Y520',
#   '13 reviews'],
#  ['Toshiba Portege X30-D-10J Black/Blue, 13.3" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1203.41',
#   'Toshiba Portege X30 D 10J Black Blue',
#   '13 reviews'],
#  ['Lenovo ThinkPad E31-80, 13.3" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home',
#   '$404.23',
#   'Lenovo ThinkPad E31 80',
#   '12 reviews'],
#  ['Moon Silver, 15.6", Core i7-4510U, 8GB, 1TB, Radeon HD R7 M265 2GB,',
#   '$745.99',
#   'Inspiron 15',
#   '12 reviews'],
#  ['MSI GL62M 7REX2, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home',
#   '$1199.00',
#   'MSI GL62M 7REX2',
#   '12 reviews'],
#  ['Lenovo Yoga 720 Grey, 15.6" FHD IPS, Core i5-7300HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, Windows 10 Home',
#   '$1149.73',
#   'Lenovo Yoga 720 Grey',
#   '12 reviews'],
#  ['Lenovo ThinkPad Yoga 370 Black, 13.3" FHD IPS Touch, Core i5-7200U, 8GB, 256GB SSD, 4G, Windows 10 Pro',
#   '$1362.24',
#   'Lenovo ThinkPad Yoga 370 Black',
#   '12 reviews'],
#  ['Hewlett Packard 250 G6 Dark Ash Silver, 15.6" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS',
#   '$364.46',
#   'Hewlett Packard 250 G6 Dark Ash Silver',
#   '12 reviews'],
#  ['Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   '$299.00',
#   'Prestigio SmartBook 133S Gold',
#   '12 reviews'],
#  ['12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro 64bit',
#   '$1311.99',
#   'ThinkPad X240',
#   '12 reviews'],
#  ['Dell Latitude 5480, 14" FHD, Core i7-7600U, 8GB, 256GB SSD, Linux + Windows 10 Home',
#   '$1338.37',
#   'Dell Latitude 5480',
#   '11 reviews'],
#  ['Lenovo ThinkPad L570, 15.6" FHD, Core i7-7500U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$999.00',
#   'Lenovo ThinkPad L570',
#   '11 reviews'],
#  ['Toshiba Portege X20W-D-10V Black/Blue, 12.5" FHD Touch, Core i7-7500U, 8GB, 512GB SSD, Windows 10 Pro',
#   '$1366.32',
#   'Toshiba Portege X20W D 10V Black Blue',
#   '11 reviews'],
#  ['MSI GP62M 7RDX Leopard, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home',
#   '$1149.00',
#   'MSI GP62M 7RDX Leopard',
#   '11 reviews'],
#  ['Lenovo Legion Y520-15IKBM, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 1TB, GeForce GTX 1060 Max-Q 6GB, DOS',
#   '$1149.00',
#   'Lenovo Legion Y520 15IKBM',
#   '11 reviews'],
#  ['Apple MacBook Air 13", Intel Core i5 1.8GHz, 8GB, 256GB SSD, Intel HD 6000, RUS',
#   '$1347.78',
#   'Apple MacBook Air 13',
#   '11 reviews'],
#  ['Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1060 3GB, Windows 10 Home, Eng kbd',
#   '$1399.00',
#   'Asus ROG Strix GL702VM GC146T',
#   '10 reviews'],
#  ['Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home',
#   '$408.98',
#   'Acer Aspire 3 A315 31 Black',
#   '10 reviews'],
#  ['15.6", Core i5-4200U, 4GB, 750GB, Radeon HD8670M 2GB, Windows',
#   '$577.99',
#   'HP 350 G1',
#   '10 reviews'],
#  ['Dell Inspiron 17 2in1 (7779) Silver, 17.3" FHD Touch, Core i5-7200U, 12GB, 1TB, GeForce GT940MX 2GB, Windows 10 Home',
#   '$1124.20',
#   'Dell Inspiron 17 2in1 7779 Silver',
#   '10 reviews'],
#  ['Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home',
#   '$391.48',
#   'Acer Aspire 3 A315 31 Black',
#   '10 reviews'],
#  ['12.5", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pro 64bit',
#   '$1244.99',
#   'ThinkPad X230',
#   '10 reviews'],
#  ['Asus VivoBook Pro 15 N580VN-FI006T Gold Metal, 15.6" UHD, Core i7-7700HQ, 16GB, 1TB + 256GB SSD, GeForce MX150 2GB, Windows 10 Home, Eng kbd',
#   '$1235.49',
#   'Asus VivoBook Pro 15 N580VN FI006T Gold Metal',
#   '10 reviews'],
#  ['Dell Latitude 5580, 15.6" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1144.40',
#   'Dell Latitude 5580',
#   '10 reviews'],
#  ['Acer Aspire A315-51-33TG, Black 15.6" HD, Core i3-7100U, 4GB DDR4, 128GB SSD, Windows 10 Home, ENG',
#   '$457.38',
#   'Acer Aspire A315 51 33TG',
#   '9 reviews'],
#  ['Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 4GB, Windows 10 Home',
#   '$1221.58',
#   'Acer Predator Helios 300 PH317 51',
#   '9 reviews'],
#  ['Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Linux',
#   '$379.95',
#   'Acer Aspire ES1 572 Black',
#   '9 reviews'],
#  ['Acer Aspire 3 A315-21, 15.6", AMD A4-9120. 4GB. 128GB SSD, Linux',
#   '$393.88',
#   'Acer Aspire 3 A315 21',
#   '9 reviews'],
#  ['Lenovo V110-15ISK, 15.6" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home',
#   '$409.63',
#   'Lenovo V110 15ISK',
#   '9 reviews'],
#  ['Lenovo V510 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home',
#   '$487.80',
#   'Lenovo V510 Black',
#   '9 reviews'],
#  ['Acer Aspire ES1-572 Black, 15.6" HD, Core i5-7200U, 4GB, 500GB, Linux',
#   '$454.62',
#   'Acer Aspire ES1 572 Black',
#   '9 reviews'],
#  ['Dell Vostro 15 (3568) Red, 15.6" HD, Core i5-7200U, 4GB, 1TB, Radeon R5 M420 2GB, Linux',
#   '$497.17',
#   'Dell Vostro 15 3568 Red',
#   '9 reviews'],
#  ['Acer Aspire A515-51-5654, Black, 15.6", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG',
#   '$679.00',
#   'Acer Aspire A515 51 5654',
#   '9 reviews'],
#  ['Asus ROG Strix GL553VD-DM535T, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home, Eng kbd',
#   '$1099.00',
#   'MSI GL72M 7RDX',
#   '9 reviews'],
#  ['Asus ROG Strix SCAR Edition GL503VM-ED115T, 15.6" FHD 120Hz, Core i7-7700HQ, 16GB, 256GB SSD + 1TB SSHD, GeForce GTX 1060 6GB, Windows 10 Home',
#   '$1799.00',
#   'Asus ROG Strix SCAR Edition GL503VM ED115T',
#   '8 reviews'],
#  ['Lenovo Legion Y720, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 2TB HDD, GeForce GTX 1060 6GB, DOS, RGB backlit keyboard',
#   '$1399.00',
#   'Lenovo Legion Y720',
#   '8 reviews'],
#  ['14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit',
#   '$739.99',
#   'ProBook',
#   '8 reviews'],
#  ['Lenovo V510 Black, 14" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home',
#   '$484.23',
#   'Lenovo V510 Black',
#   '8 reviews'],
#  ['Asus ROG Strix GL702ZC-GC209T, 17.3" FHD IPS, Ryzen 7 1700, 16GB, 256GB SSD + 1TB HDD, Radeon RX 580 4GB, Windows 10 Home',
#   '$1769.00',
#   'Asus ROG Strix GL702ZC GC209T',
#   '8 reviews'],
#  ['Apple MacBook Air 13", i5 1.8GHz, 8GB, 256GB SSD, Intel HD 6000, ENG',
#   '$1260.13',
#   'Apple MacBook Air 13',
#   '8 reviews'],
#  ['Dell Latitude 5480, 14" FHD, Core i7-7600U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1310.39',
#   'Dell Latitude 5480',
#   '8 reviews'],
#  ['Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   '$299.00',
#   'Prestigio SmartBook 133S Dark Grey',
#   '8 reviews'],
#  ['Dell Latitude 5280, 12.5" HD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1102.66',
#   'Dell Latitude 5280',
#   '8 reviews'],
#  ['Hewlett Packard Spectre 13-v106na Dark Ash Silver, 13.3" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Home',
#   '$1273.11',
#   'Hewlett Packard Spectre 13 v106na Dark Ash Silver',
#   '8 reviews']]

# %%
# when review = 14
SearchbyReview(14)
# Out:
# [['Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   '$295.99',
#   'Asus VivoBook X441NA GA190',
#   '14 reviews'],
#  ['Asus ZenBook UX530UX-FY040T Blue, 15.6" FHD, Core i7-7500U, 8GB, 512GB SSD, GeForce GTX950M 2GB, Windows 10 Home, Eng kbd',
#   '$1239.20',
#   'Asus ZenBook UX530UX FY040T Blue',
#   '14 reviews'],
#  ['Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home',
#   '$1187.98',
#   'Acer Predator Helios 300 PH317 51',
#   '14 reviews'],
#  ['Acer Nitro 5 AN515-51, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD +1TB, GeForce GTX 1050 Ti 4GB, Windows 10 Home + Windows 10 Home',
#   '$1140.62',
#   'Acer Nitro 5 AN515 51',
#   '14 reviews'],
#  ['Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 500GB, Windows 10 Pro',
#   '$1133.82',
#   'Dell Latitude 5480',
#   '14 reviews'],
#  ['Lenovo ThinkPad L460, 14" FHD IPS, Core i7-6600U, 8GB, 256GB SSD, Windows 10 Pro',
#   '$1096.02',
#   'Lenovo ThinkPad L460',
#   '14 reviews'],
#  ['Dell Vostro 15 (3568) Black, 15.6" FHD, Core i5-7200U, 4GB, 128GB SSD, Radeon R5 M420 2GB, Linux',
#   '$488.78',
#   'Dell Vostro 15',
#   '14 reviews'],
#  ['Acer Aspire ES1-732 Black, 17.3" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home',
#   '$410.46',
#   'Acer Aspire ES1 732 Black',
#   '14 reviews']]

# %% [markdown]
# ## End of Notebook
